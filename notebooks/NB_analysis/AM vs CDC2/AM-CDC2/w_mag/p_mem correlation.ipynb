# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table, hstack, vstack
from clevar.catalog import ClCatalog
from astropy.io import ascii

# %%
inpath1 = "/sps/lsst/groups/clusters/amico_validation_project/catalogs/AMICO/amico_cats/amico_map_associations_flxzb_mag/mag_i/"

# %%
am_mb_all = Table.read(inpath1 + 'all_maps.fits')

# %%
am_mb_all
# Out:
# <Table length=48913706>
#   mb_id    cl_id     prob    ...       mag_z              mag_y
#   int64    int64   float32   ...      float64            float64
# ---------- ----- ----------- ... ------------------ ------------------
# 9437510655     7  0.08503411 ... 24.217455126447188 24.099657274884688
# 9437518527     7    0.383052 ...  24.07782468287023  23.92252454248937
# 9437520066     7   0.0845746 ... 24.719030945009436  24.58740100116178
# 9437525515     7 0.048780423 ... 24.002323042298467 23.898752104188116
# 9437538932     7   0.2377326 ...  22.80600048067961 22.538017997769455
# 9437546477     7  0.11205486 ... 24.143799184801793 23.959812520983434
# 9437547708     7   0.1653368 ...  24.70000974406592 24.587483804124513
# 9437549285     7  0.14656283 ... 23.732315364232967 23.540010753026912
# 9437551595     7    0.153697 ... 24.664094562207392  24.49681627241247
# 9437575830     7   0.3388556 ... 24.152955855000982 23.969283903707037
# ...

# %%
plt.scatter(am_mb_all['f_prob'], am_mb_all['prob'], alpha =.3, s=.0001)
plt.xlabel('f_prob')
plt.ylabel('p_mem')
# Out:
# Text(0, 0.5, 'p_mem')

# %%
inpath = "/sps/lsst/groups/clusters/amico_validation_project/catalogs/matching_cats/amico_cosmoDC2/mag_i/w_rich/m14/cuts/"

# %%
am_mb = Table.read(inpath + 'c1_p_members.fits')

# %%
am_mb
# Out:
# <Table length=3603491>
#     id     id_cluster     ra    ...       mag_y            sn    ind_cl
#  bytes21    bytes21    float64  ...      float64        float64  int64
# ---------- ---------- --------- ... ------------------ --------- ------
# 9437510655          1 50.113525 ... 24.099657274884688  8.411978      0
# 9437518527          1 50.113525 ...  23.92252454248937  8.411978      0
# 9437520066          1 50.113525 ...  24.58740100116178  8.411978      0
# 9437525515          1 50.113525 ... 23.898752104188116  8.411978      0
# 9437538932          1 50.113525 ... 22.538017997769455  8.411978      0
# 9437546477          1 50.113525 ... 23.959812520983434  8.411978      0
# 9437547708          1 50.113525 ... 24.587483804124513  8.411978      0
# 9437549285          1 50.113525 ... 23.540010753026912  8.411978      0
# 9437551595          1 50.113525 ...  24.49681627241247  8.411978      0
# 9437575830          1 50.113525 ... 23.969283903707037  8.411978      0
# ...

# %%
plt.scatter(am_mb['f_prob'], am_mb['pmem'], alpha =.3, s=.001)
plt.xlabel('f_prob')
plt.ylabel('p_mem')
# Out:
# Text(0, 0.5, 'p_mem')
