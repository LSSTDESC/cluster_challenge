# %% [markdown]
# # To begin

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib
# %matplotlib inline
import GCRCatalogs
from GCRCatalogs.helpers.tract_catalogs import tract_filter, sample_filter
from GCRCatalogs import GCRQuery
import numpy as np
from matplotlib.patches import Rectangle
from astropy.table import Table, vstack
from astropy.coordinates import SkyCoord
from astropy import units as u
from astropy.cosmology import FlatLambdaCDM
from astropy.io import fits
from astropy.io import ascii
import sys
import os
import shutil
import pickle
import healpy as hp
import h5py
import pandas as pd

###clevar
import clevar
from clevar import ClCatalog
from clevar.match import ProximityMatch
from clevar.match_metrics import scaling
from clevar.match_metrics import recovery
from clevar.match_metrics import distances
from clevar.match import get_matched_pairs
from clevar.match import output_matched_catalog

# %% [markdown]
# ### Loading Matching's results

# %%
cat_names = ['9943_map_associations', '9942_map_associations', '9816_map_associations', '9815_map_associations', '9814_map_associations', '9687_map_associations', '9686_map_associations',
             '9559_map_associations', '10450_map_associations', '10327_map_associations', '10326_map_associations', '10200_map_associations', '10199_map_associations',
             '10198_map_associations', '10072_map_associations', '10071_map_associations']

# %%
all_amico_data_members = Table.read('/sps/lsst/groups/clusters/amico_validation_project/catalogs/amico_cats/new_amico_map_associations_cut/all_maps_cut.fits')
"""for name in cat_names[1:]:
    cat_path = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/amico/amico_map_associations/' + name + '.fits'
    amico_data1 = Table.read(cat_path)
    amico_data_members = vstack([amico_data_members, amico_data1])"""
# Out:
# "for name in cat_names[1:]:\n    cat_path = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/amico/amico_map_associations/' + name + '.fits'\n    amico_data1 = Table.read(cat_path)\n    amico_data_members = vstack([amico_data_members, amico_data1])"

# %%
amico_data_members = Table.read('/sps/lsst/groups/clusters/amico_validation_project/catalogs/amico_cats/new_amico_map_associations_cut/' + cat_names[0] + '.fits')

# %%
all_amico_data_members
# Out:
# <Table length=10595337>
#   mb_id    cl_id     prob       uid   ...         z           lambstar     SN
#   int64    int64   float32    float64 ...      float64        float64   float64
# ---------- ----- ------------ ------- ... ------------------ --------- ---------
# 8937506729     5   0.29497647 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# 8937513364     5   0.28917313 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# 8937514977     5   0.07473981 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# 8937519516     5   0.17177144 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# 8937520312     5   0.07378859 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# 8937520815     5   0.09998231 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# 8937522109     5  0.022967089 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# 8937522427     5   0.27252233 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# ...

# %%
amico_data_members
# Out:
# <Table length=658101>
#   mb_id    cl_id     prob      uid   ...         z           lambstar     SN
#   int64    int64   float32   float64 ...      float64        float64   float64
# ---------- ----- ----------- ------- ... ------------------ --------- ---------
# 8937506729     5  0.29497647 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# 8937513364     5  0.28917313 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# 8937514977     5  0.07473981 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# 8937519516     5  0.17177144 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# 8937520312     5  0.07378859 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# 8937520815     5  0.09998231 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# 8937522109     5 0.022967089 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# 8937522427     5  0.27252233 19317.0 ... 0.5299999713897705 64.097006 8.8714556
# ...

# %%
colors = ['b', 'g', 'c', 'm', 'y', 'r', 'k', 'tab:blue', 'tab:orange', 'tab:purple','tab:brown', 'tab:green', 'tab:pink', 'tab:purple', 'yellow', 'darkviolet']

# %%
tile_names = []
for i in range(len(cat_names)):
    tile_names.append(cat_names[i].split("_")[0])

# %%
plt.figure(figsize = (20,20))      
for i, tile in enumerate(tile_names):
    path_to_cat = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/amico_cats/new_amico_map_associations_cut/' + tile + '_map_associations.fits'
    amico_data_detec_tile = Table.read(path_to_cat)
    ra = amico_data_detec_tile['ra']
    dec = amico_data_detec_tile['dec']
    plt.scatter(ra, dec, color = colors[i], label = 'tile =' + tile, alpha = .5)

#plt.legend(fontsize = 20)

# %%
plt.scatter(all_amico_data_members['ra'], all_amico_data_members['dec'], alpha = .25)

# %%
cl_inpath = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/130323/cosmoDC2_small_photoz_flexzboost_v0/map_detections_refined_noBuffer_all_noDoubles.fits'
amico_cl_data = Table.read(cl_inpath)['ID', 'Xphys', 'Yphys', 'Zphys','LAMBSTAR', 'SN_NO_CLUSTER', 'SN', 'UID', 'TILE', 'LAMB']

# %%
amico_cl_data
# Out:
# <Table length=20509>
#   ID    Xphys     Yphys     Zphys   LAMBSTAR SN_NO_CLUSTER     SN     UID   TILE
# int16  float64   float64   float32  float64     float64     float64  int16 int16
# ----- --------- ---------- ------- --------- ------------- --------- ----- -----
#     2 61.379151 -39.997938    0.76 151.05119     87.011334 10.992644     1 10070
#     4 61.751903 -39.598934    0.39 34.635494     45.503782 8.6246391     2 10070
#     7 62.020461  -40.78391    0.76 65.485061     47.128286 8.0360327     3 10070
#    10 62.622221  -40.86162    0.26 35.691697      30.95731 7.1248405     4 10070
#    11 61.527245 -40.393481    0.74 49.109488     35.746636 7.0846547     5 10070
#    13 62.669286 -39.811269    0.38 22.831824     26.760903 6.6516001     6 10070
#    16 61.321316  -40.68769    1.33 40.708297     41.626933 6.4476733     7 10070
#    18 61.378259 -41.012951    0.44   26.0136     33.226036 6.4235022     8 10070
# ...

# %% [markdown]
# ### Here I check if there are no double w/ position. Could do the same with uid

# %%
lisstra = [0]
lisstdec = [0]
lisstz = [0]
doublon=[0]
lisstpos=[]
pos_table = amico_cl_data['Xphys', 'Yphys', 'Zphys']
for ra, dec, z in pos_table:
    if [ra, dec, z] not in lisstpos:
        lisstpos.append([ra,dec,z])
    #if ra in lisstra and dec in lisstdec and z in lisstz:
    #    doublon.append(ra)

# %%
len(lisstpos), len(amico_cl_data['Xphys'])
# Out:
# (20509, 20509)

# %%
listuid = []
for uid in amico_cl_data['UID']:
    if uid not in listuid:
        listuid.append(uid)

# %%
len(listuid)
# Out:
# 20509

# %%
ra_miss=[]
for ra in amico_cl_data['Xphys']:
    if ra not in lisstra:
        ra_miss.append(ra)

# %%
len(ra_miss)
# Out:
# 0

# %% [markdown]
# ### Display cats to see variables names etc..

# %%
Table.read('/sps/lsst/users/tguillem/DESC/desc_april_2022/cluster_challenge/clevar_catalogs/cosmoDC2/cosmoDC2_v1.1.4_small/Catalog.fits')
# Out:
# <Table length=61725>
#       id              ra         ...       m200c            log_m200c
#     int64          float64       ...      float64            float64
# ------------- ------------------ ... ------------------ ------------------
#     400155487 61.869596337556686 ... 10371945197971.832 13.015860213430779
#   37900155453 61.295572557486395 ...  9864409307222.535 12.994071084287206
#   14700155442 62.961217514835056 ... 19093749298478.875 13.280891215966287
#    3300155432 62.284364037836404 ... 12914829133160.564 13.111088664708609
#   19800155432  62.05549212472633 ...  11483317608563.38 13.060067376819875
#   41300155432  62.10249971222131 ...  12698800324146.48 13.103762694403757
#   22500155421  61.05606039634485 ... 23026498568653.523 13.362227903751352
#   35700155421  62.23579865478711 ...  85281595830445.08 13.930855318486811
#   51800155421  61.97682173294707 ...  7901938771650.705 12.897733660217959
# ...

# %%
Table.read('/sps/lsst/users/tguillem/DESC/desc_april_2022/cluster_challenge/clevar_catalogs/cosmoDC2/cosmoDC2_v1.1.4_small/Catalog_members.fits')
# Out:
# <Table length=1412270>
#     id       id_cluster          ra         ...          z            pmem
#   int64        int64          float64       ...       float64       float64
# ---------- ------------- ------------------ ... ------------------- -------
# 9687500005     400155487  61.49201043033873 ...  0.0211994336529282     1.0
# 9687500006     400155487 61.752069643381446 ... 0.01895143717971748     1.0
# 9687502265   37900155453 61.333870100549795 ... 0.09387069271538051     1.0
# 9687502266   37900155453  61.30112057904649 ... 0.09415744743441423     1.0
# 9687502267   37900155453  61.30703551395186 ... 0.09377420336904363     1.0
# 9687502268   37900155453   61.3099571986797 ... 0.09478376411004019     1.0
# 9687502269   37900155453  61.31394110141341 ... 0.09388141269950756     1.0
# 9687502270   37900155453 61.309789177802664 ... 0.09355094139155318     1.0
# 9687502271   37900155453  61.53708024138936 ... 0.09445259437167319     1.0
# ...

# %%
Table.read('/sps/lsst/groups/clusters/amico_validation_project/catalogs/amico_cats/new_amico_map_associations_cut/Catalog.fits')
# Out:
# <Table length=20509>
#   id      ra       dec        z       mass
# int16  float64   float64   float32  float64
# ----- --------- ---------- ------- ---------
#     1 61.379151 -39.997938    0.76 151.05119
#     2 61.751903 -39.598934    0.39 34.635494
#     3 62.020461  -40.78391    0.76 65.485061
#     4 62.622221  -40.86162    0.26 35.691697
#     5 61.527245 -40.393481    0.74 49.109488
#     6 62.669286 -39.811269    0.38 22.831824
#     7 61.321316  -40.68769    1.33 40.708297
#     8 61.378259 -41.012951    0.44   26.0136
#     9 61.503286 -41.168414    0.38 24.052439
#    10 60.878596 -39.859705    0.68 37.570579
#   ...       ...        ...     ...       ...
# 20500 65.212334 -38.119664    1.29 9.1138835
# 20501 65.775493 -38.677568    0.77 5.8326684
# 20502 64.831162 -38.836225    0.98 10.975485
# 20503 65.193177 -39.144567     0.7 8.3780756
# 20504 66.544196  -39.71715    0.64 5.1407113
# 20505  66.11524 -39.677998    0.88 12.540215
# ...

# %%
Table.read('/sps/lsst/groups/clusters/amico_validation_project/catalogs/amico_cats/new_amico_map_associations_cut/Catalog_members.fits')
# Out:
# <Table length=10595337>
#     id     id_cluster     ra    ...         z              pmem      lambstar
#   int64      int64     float64  ...      float64         float32     float64
# ---------- ---------- --------- ... ------------------ ------------ ---------
# 8937506729      19317 65.701707 ... 0.5299999713897705   0.29497647 64.097006
# 8937513364      19317 65.701707 ... 0.5299999713897705   0.28917313 64.097006
# 8937514977      19317 65.701707 ... 0.5299999713897705   0.07473981 64.097006
# 8937519516      19317 65.701707 ... 0.5299999713897705   0.17177144 64.097006
# 8937520312      19317 65.701707 ... 0.5299999713897705   0.07378859 64.097006
# 8937520815      19317 65.701707 ... 0.5299999713897705   0.09998231 64.097006
# 8937522109      19317 65.701707 ... 0.5299999713897705  0.022967089 64.097006
# 8937522427      19317 65.701707 ... 0.5299999713897705   0.27252233 64.097006
# 8937524520      19317 65.701707 ... 0.5299999713897705   0.18709254 64.097006
# ...

# %%
amico_cl_data['UID', 'LAMB']
# Out:
# <Table length=20509>
#  UID     LAMB
# int16  float64
# ----- ---------
#     1 563.08723
#     2 325.80262
#     3 277.82817
#     4 237.63314
#     5 259.19082
#     6 208.87301
#     7 151.75732
#     8 280.16731
#     9 219.63575
#    10 213.81887
#   ...       ...
# 20500 33.885892
# 20501 34.408338
# 20502 37.396483
# 20503 42.348888
# 20504 43.003822
# 20505 47.865108
# 20506 43.711099
# 20507 34.038671
# 20508 34.611755
# 20509 40.871352

# %%
5000%1000
# Out:
# 0

# %%
est_rich = []
for uid in amico_cl_data['UID']:
    if uid%1000 ==0 :
        print(uid)
    est_rich.append(sum(all_amico_data_members[(all_amico_data_members['uid'].astype(int) == uid)]['prob']))

# %%
len(rich)
# Out:
# 20509

# %%
rich = amico_cl_data['LAMB']
delta = [(rich[i] - est_rich[i]) for i in range(len(est_rich))]

# %%
plt.hist(delta, bins = 5000)
plt.xlim([0,10])
# Out:
# (0.0, 10.0)

# %%
plt.scatter(rich, delta, marker = '+')
plt.xlabel('$\lambda$',fontsize = 15)
plt.ylabel('$\Delta = \lambda - \lambda_{est}$',fontsize = 15)
# Out:
# Text(0, 0.5, '$\\Delta = \\lambda - \\lambda_{est}$')

# %%
len(all_amico_data_members[(all_amico_data_members['uid'] == amico_cl_data['UID'][0])]['prob'])
# Out:
# 11084

# %%
mbl = []
for mb in all_amico_data_members['mb_id']:
    if mb not in mbl:
        mbl.append(mb)

# %%
len(mbl)

# %%
len(all_amico_data_members[(all_amico_data_members['uid'] == uid)])

# %%
len(all_amico_data_members[(all_amico_data_members['uid'].astype(int) == uid)])

# %%
amico_data_mem1 = Table.read('/sps/lsst/groups/clusters/amico_validation_project/catalogs/amico_map_associations/' + cat_names[0] + '.fits')
amico_data1 = amico_data[amico_data['tile'] == 9943]

# %%
ID_l = []
for ID in amico_data1['ID']:
    if ID in amico_data_mem1['halo_id'] and ID not in ID_l:
        ID_l.append(ID)

# %%
LAMB = amico_data1[amico_data1['ID'] == ID]['LAMBSTAR']
nb = len(amico_data_mem1[amico_data_mem1['halo_id'] == ID])

# %%
lambstar_l=[]
nb_l = []
for ID in ID_l:
    LAMBSTAR = float(amico_data1[amico_data1['ID'] == ID]['LAMBSTAR'])
    nb = len(amico_data_mem1[(amico_data_mem1['halo_id'] == ID) * (amico_data_mem1['prob'] >= .7)])
    lambstar_l.append(LAMBSTAR)
    nb_l.append(nb)

# %%
plt.hist(nb_l, bins = 25, density = True, alpha = .5, label = 'nb_members')
plt.hist(lambstar_l, bins = 25, density =  True, alpha = .5, label = 'richness')
plt.xlabel('nb of members/richness')
plt.legend()
plt.show()

# %%
lambstar_l=[]
nb_l = []
for ID in amico_cl_data_9943['ID']:
    LAMBSTAR = float(amico_cl_data_9943[amico_cl_data_9943['ID'] == ID]['LAMBSTAR'])
    nb = len(amico_mb_data[(amico_mb_data['halo_id'] == ID)])
    lambstar_l.append(LAMBSTAR)
    nb_l.append(nb)

# %%
plt.hist(nb_l, bins = 25, density = True, alpha = .5, label = 'nb_members')
plt.hist(lambstar_l, bins = 25, density =  True, alpha = .5, label = 'richness')
plt.xlabel('nb of members/richness')
plt.legend()
plt.show()

# %%
plt.hist(amico_mb_data['prob'], bins = 25, density =  True)
plt.xlabel('membership probability')
plt.ylabel('Normalized number of clusters')
plt.show()
