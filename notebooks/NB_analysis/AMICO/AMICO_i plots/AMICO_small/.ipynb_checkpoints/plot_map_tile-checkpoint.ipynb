# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
from astropy.table import Table, vstack
import GCRCatalogs
from GCRCatalogs.helpers.tract_catalogs import tract_filter, sample_filter
from GCRCatalogs import GCRQuery
import pandas as pd

# %%
path_to_cat = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/130323/cosmoDC2_small_photoz_v1/DETECTIONS_DERIVED/9943_map_associations_noBuffer.cat'
amico_data_asso = Table.read(path_to_cat, format='ascii')

# %%
cat_names = ['9943_map_associations', '9942_map_associations', '9816_map_associations', '9815_map_associations', '9814_map_associations', '9687_map_associations', '9686_map_associations',
             '9559_map_associations', '10450_map_associations', '10327_map_associations', '10326_map_associations', '10200_map_associations', '10199_map_associations',
             '10198_map_associations', '10072_map_associations', '10071_map_associations']
tile_names = []
for i in range(len(cat_names)):
    tile_names.append(cat_names[i].split("_")[0])

# %%
amico_data_asso
# Out:
# <Table length=490962>
#     col1                   col2
#    int64                  str178
# ----------- ---------------------------------
#  7062528436   0.87593555\t1\t358\t0.037188705
#  7062532548   0.70145613\t1\t358\t0.016173925
#  7062539979  0.88780063\t1\t358\t0.0060230014
#  7062545119   0.77349001\t1\t358\t0.010921772
#  7062545655   0.85093588\t1\t358\t0.019238569
#  7062550527   0.86246574\t1\t358\t0.016114991
#  7062554561   0.88835144\t1\t358\t0.018428797
#  7062558883    0.78846842\t1\t358\t0.10524256
#  7062559941   0.87057877\t1\t358\t0.035458568
#  7062560803   0.85181534\t1\t358\t0.047897957
#         ...                               ...
# 10566199282  0.95994598\t1\t1235\t0.024554608
# 10566206836  0.94222194\t1\t1235\t0.011229768
# 10566218409 0.97354883\t1\t1235\t0.0074935751
# 10566220540  0.89950287\t1\t1235\t0.037039898
# 10566425318 0.95667672\t1\t1235\t0.0092813056
# 10566508715  0.91102707\t1\t1235\t0.027660361
# 10566532646  0.95038837\t1\t1235\t0.019906919
# 10566532959  0.96911073\t1\t1235\t0.007406082
# 10566539027  0.89001137\t1\t1235\t0.025992831
# 10566544574  0.9683038\t1\t1235\t0.0072747464

# %%
path_to_cat = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/130323/cosmoDC2_small_photoz_v1/DETECTIONS_DERIVED/9943_map_detections_refined_noBuffer.cat'
amico_data_detec = Table.read(path_to_cat, format='ascii')

# %%
len(amico_data_detec)
# Out:
# 642

# %%
amico_data_detec
# Out:
# <Table length=642>
#  col1  col2  col3  col4 ...     col137        col138        col139
# int64 int64 int64 int64 ...    float64       float64       float64
# ----- ----- ----- ----- ... ------------- ------------- -------------
#     3   195   459    50 ... 0.00017611902 0.00018094807 0.00018545504
#    14   207   256    35 ... 0.00027995586 0.00028160319 0.00028152418
#    18   231   448    62 ... 7.3035721e-05 7.6724878e-05  8.098672e-05
#    19   217   528    48 ... 0.00021923508 0.00022669442 0.00023294645
#    22   213   573    44 ... 0.00024806199 0.00024946182 0.00025078625
#    27   254   465    62 ... 9.4659401e-05 9.8995384e-05 0.00010348828
#    28   205   277   117 ...   0.094649337   0.097389959   0.095652394
#    29   146   477    66 ... 5.1599189e-05 5.3359181e-05 5.5465109e-05
#    34   228   370    44 ... 0.00028345559 0.00028978786 0.00029533365
#    36   203   537    28 ... 0.00054964854 0.00054498384 0.00053668831
#   ...   ...   ...   ... ...           ...           ...           ...
#  1710    72   331    69 ... 4.1706666e-05 4.3282311e-05 4.5555753e-05
#  1712   286   262   107 ...   0.027543982     0.0238645   0.020380041
#  1713   177   249    59 ... 0.00010866753 0.00011443777 0.00012062094
#  1720   363   363   110 ...    0.05021048   0.041859966   0.034657609
#  1721   293   589   108 ...   0.034465548   0.029342419   0.024719061
#  1724   223   517   114 ...   0.087060638   0.078553811   0.067528255
#  1729   307   388    99 ...  0.0042450088   0.003855021  0.0034753201
#  1733   235   547    77 ... 5.2314554e-05 5.1741168e-05 5.1717263e-05
#  1737   415   283   100 ...  0.0092383707  0.0083309049  0.0074445778
#  1738   345   288   104 ...   0.019022103   0.016308175   0.013867761

# %%
inpath = '/sps/lsst/users/tguillem/DESC/desc_april_2022/cluster_challenge/clevar_catalogs/amico/map_detections_refined_noBuffer_all.fits'
amico_cl_data = Table.read(inpath)['ID', 'Xphys', 'Yphys', 'Zphys','LAMBSTAR', 'SN_NO_CLUSTER', 'SN', 'uid', 'tile']

# %%
len(amico_cl_data[amico_cl_data['tile'] == 9943])
# Out:
# 642

# %%
#with cut
def cat_to_df_cut(table, cut):
    new_table = {'mb_id' : [], 'nb_halo' : [], 'halo_id' : [], 'prob' : []}
    for i in range(len(table['col2'])):
        n = table['col2'][i].count('\t')
        cat_split = table['col2'][i].split("\t", n)
        n_detec = int(cat_split[1])
        for j in range(n_detec):
            if (float(cat_split[-1-j]) >= cut):               
                new_table['mb_id'].append(int(table['col1'][i]))
                new_table['nb_halo'].append(1+j)
                new_table['halo_id'].append(int(cat_split[2+j]))
                new_table['prob'].append(float(cat_split[-1-j]))
    df = pd.DataFrame(new_table)
    return df

# %%
plt.scatter(amico_data_detec['col5'], amico_data_detec['col6'])

# %%
cat_to_df_cut(amico_data_asso, .5)
# Out:
#             mb_id  nb_halo  halo_id      prob
# 0      8000083376        1      234  0.629373
# 1      8000111079        1      234  0.610933
# 2      8000111080        1      234  0.660140
# 3      8000115019        2       22  0.522982
# 4      8000188768        1      234  0.576604
# ...           ...      ...      ...       ...
# 17166  9815593555        1     1076  0.686052
# 17167  9816182539        1      967  0.612278
# 17168  9816183680        1     1076  0.736547
# 17169  9816183686        1     1076  0.904007
# 17170  9816215003        1      967  0.589028
#
# [17171 rows x 4 columns]

# %%
len(tile_names)
# Out:
# 16

# %%
colors = ['b', 'g', 'c', 'm', 'y', 'r', 'k', 'tab:blue', 'tab:orange', 'tab:purple','tab:brown', 'tab:green', 'tab:pink', 'tab:purple', 'yellow', 'darkviolet']

# %%
figure, axes = plt.subplots(figsize = (20,20))      
for i, tile in enumerate(tile_names):
    path_to_cat = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/AMICO/amico_cats/amico_map_associations/' + tile + '_map_associations.fits'
    amico_data_detec_tile = Table.read(path_to_cat)
    ra = amico_data_detec_tile['ra']
    dec = amico_data_detec_tile['dec']
    axes.scatter(ra, dec, label = 'tile =' + tile)
cl_inpath = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/AMICO/raw_amico_cats/cosmoDC2_small_photoz_flexzboost_v0/map_detections_refined_noBuffer_all_noDoubles.fits'
amico_cl_data = Table.read(cl_inpath)['ID', 'Xphys', 'Yphys', 'Zphys','LAMBSTAR', 'SN_NO_CLUSTER', 'SN', 'UID', 'TILE']  
amico_cdt = amico_cl_data[(amico_cl_data['ID']==101)]
circle = plt.Circle((amico_cdt['Xphys'],amico_cdt['Yphys']),.1, color = 'red', fill = False, linewidth = 3)
axes.add_artist( circle )
ax.set_xlabel('ra', fontsize = 15)
ax.set_ylabel('dec', fontsize = 15)
axes.legend(fontsize = 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [11], line 13
#      11 circle = plt.Circle((amico_cdt['Xphys'],amico_cdt['Yphys']),.1, color = 'red', fill = False, linewidth = 3)
#      12 axes.add_artist( circle )
# ---> 13 ax.set_xlabel('ra', fontsize = 15)
#      14 ax.set_ylabel('dec', fontsize = 15)
#      15 axes.legend(fontsize = 20)
#
# NameError: name 'ax' is not defined
# Error in callback <function _draw_all_if_interactive at 0x7feaba499870> (for post_execute):

# %%
amico_cdt

# %%
 amico_cl_data[(amico_cl_data['tile']==9559)]
# Out:
# <Table length=734>
#   ID    Xphys     Yphys      Zphys    ... SN_NO_CLUSTER     SN     uid   tile
# int16  float64   float64    float64   ...    float64     float64  int16 int16
# ----- --------- ---------- ---------- ... ------------- --------- ----- -----
#     1 64.257378 -34.475754 0.31999999 ...     44.554123 8.7294683  5736  9559
#     2 64.140701 -34.695297       0.56 ...     45.688927 7.7550945  5737  9559
#     4 63.753197 -34.542969 0.39999998 ...     44.124405 7.5915031  5738  9559
#     5 65.060272 -34.990952 0.30999997 ...      30.24468 7.1570339  5739  9559
#     9 65.030769 -33.751022 0.37999997 ...     32.687096 6.7403917  5740  9559
#    11 65.112518 -34.465778 0.34999996 ...     29.179428 6.7141566  5741  9559
#    13 65.386917 -34.644531 0.44999999 ...     34.754093 6.6083479  5742  9559
#    14 63.940521 -34.639248 0.42999998 ...     33.489655 6.3732343  5743  9559
#    15 64.778259 -33.801468 0.37999997 ...     28.817041 6.3108106  5744  9559
#    16 64.880867 -33.941349       0.22 ...      23.71097 6.2582641  5745  9559
#   ...       ...        ...        ... ...           ...       ...   ...   ...
#  1230  65.59626 -33.773136 0.88999999 ...     7.1382918 3.0053682  6460  9559
#  1231 64.890808 -33.061333       1.16 ...     6.8628831  3.004668  6461  9559
#  1232 64.346977 -33.321022 0.38999999 ...     7.6461983 3.0044265  6462  9559
#  1233 66.066536  -34.20879 0.72999996 ...      10.11074 3.0040381  6463  9559
#  1234 64.465973 -33.576302 0.70999998 ...      7.716176 3.0039418  6464  9559
#  1235 63.612843 -34.126804 0.75999999 ...     8.5872869 3.0034516  6465  9559
#  1236 64.801567 -33.236446 0.97999996 ...     7.7569222 3.0031161  6466  9559
#  1238 63.602047 -34.496731 0.99999994 ...     8.1951075 3.0026348  6467  9559
#  1240 64.939209 -33.296242 0.84999996 ...     7.3376703 3.0015435  6468  9559
#  1241 65.510269 -34.208755       1.16 ...     6.8069305 3.0010016  6469  9559

# %%
amico_cl_data[(amico_cl_data['ID']==101)]
# Out:
# <Table length=8>
#   ID    Xphys     Yphys      Zphys    ... SN_NO_CLUSTER     SN     uid   tile
# int16  float64   float64    float64   ...    float64     float64  int16 int16
# ----- --------- ---------- ---------- ... ------------- --------- ----- -----
#   101 65.119835 -40.164696       1.02 ...     19.922134 4.7009764   697 10071
#   101 64.309631 -41.532894 0.60999995 ...      14.21274 4.4554496  1959 10198
#   101 66.651924 -42.711174 0.85999995 ...     15.937883 4.6884274  2526 10199
#   101 65.982376 -43.600117 0.67999995 ...     14.611876 4.4617124  3851 10326
#   101 66.614159 -35.211372       1.02 ...     20.581415 4.7823944  7152  9687
#   101 62.923534 -37.441898 0.84999996 ...     16.450939  4.718286  7953  9814
#   101 67.459045 -37.476498 0.85999995 ...     15.349977 4.5935378  9398  9816
#   101 63.006294 -38.494175 0.54999995 ...     19.101202 4.9092069 10171  9942

# %%
circle = plt.Circle((amico_cdt['Xphys'],amico_cdt['Yphys']),10, color = 'red', fill = True)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [43], line 2
#       1 figure, axes = plt.subplots()
# ----> 2 axes.add_artist(circle)
#       3 axes.show()
#
# File /sps/lsst/users/namourou/conda_clone_210223/descv1.1/lib/python3.10/site-packages/matplotlib/axes/_base.py:2254, in _AxesBase.add_artist(self, a)
#    2241 def add_artist(self, a):
#    2242     """
#    2243     Add an `.Artist` to the Axes; return the artist.
#    2244
#    (...)
#    2252     ``ax.transData``.
#    2253     """
# -> 2254     a.axes = self
#    2255     self._children.append(a)
#    2256     a._remove_method = self._children.remove
#
# File /sps/lsst/users/namourou/conda_clone_210223/descv1.1/lib/python3.10/site-packages/matplotlib/artist.py:274, in Artist.axes(self, new_axes)
#     270 @axes.setter
#     271 def axes(self, new_axes):
#     272     if (new_axes is not None and self._axes is not None
#     273             and new_axes != self._axes):
# --> 274         raise ValueError("Can not reset the axes.  You are probably "
#     275                          "trying to re-use an artist in more than one "
#     276                          "Axes which is not supported")
#     277     self._axes = new_axes
#     278     if new_axes is not None and new_axes is not self:
#
# ValueError: Can not reset the axes.  You are probably trying to re-use an artist in more than one Axes which is not supported
