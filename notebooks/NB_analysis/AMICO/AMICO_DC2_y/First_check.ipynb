# %%
import numpy as np
from astropy.table import Table
import matplotlib.pyplot as plt

# %%
path = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/AMICO/raw_amico_cats/DC2_v0_yband/'

# %%
cl = Table.read(path + 'map_detections_refined_noBuffer_all_noDoubles.fits')

# %%
cl
# Out:
# <Table length=74502>
#   ID   Xpix  Ypix  Zpix   Xphys   ...     Pz-217        Pz-218     UID   TILE
# int16 int16 int16 int16  float64  ...    float64       float64    int32 int16
# ----- ----- ----- ----- --------- ... ------------- ------------- ----- -----
#     1    67   234    24 49.683452 ... 7.0836479e-05 7.0460607e-05     1  2896
#     4    61    57   163 49.641694 ...  0.0092216506  0.0090972324     2  2896
#     6    86    99    88 49.816505 ... 6.4415521e-05 5.7337347e-05     3  2896
#     7    69   159    31 49.697499 ... 0.00020019568 0.00020493312     4  2896
#    10    75   128    33 49.739429 ... 0.00032943358  0.0003249587     5  2896
#    11    82   155    13 49.787948 ... 0.00012589231 0.00010657026     6  2896
#    13    56    66   196 49.606663 ...   0.035361184   0.034964973     7  2896
#    17    57   144    25 49.613987 ... 0.00016039112 0.00016089291     8  2896
#    21    67   160   162 49.683589 ...  0.0028778889  0.0029618251     9  2896
# ...

# %%
plt.scatter(cl['Xphys'], cl['Yphys'])

# %%
cl_by_name = cl.group_by('TILE')

# %%
cl_by_name.groups.keys['TILE'][:]
# Out:
# <Column name='TILE' dtype='int16' length=151>
# 2896
# 2897
# 2898
# 2899
# 2900
# 2901
# 2902
# 2903
# 2904
# 2905
# 2906
# 2907
#  ...
# 4859
# 4860
# 5065
# 5066
# 5067
# 5068
# 5069
# 5070
# 5071
# 5072
# 5073
# 5074
