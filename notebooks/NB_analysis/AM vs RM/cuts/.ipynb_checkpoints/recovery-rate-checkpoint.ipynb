# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table, hstack, vstack
from clevar.catalog import ClCatalog
from numpy.ma import masked
import sys
from clevar.match import output_matched_catalog
from clevar.match_metrics import recovery

# %%
path = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/matching_cats/amico_redmapper/mag_i/cut/'
c1 = ClCatalog.read(path + 'c1_p_ls1438z115.fits', 'c1', full=True)

# %%
c2 = ClCatalog.read(path + 'c2_p_ls1438z115.fits', 'c2', full=True)

# %%
plt.hist(c1['mass'], bins = 100)
plt.hist(c2['mass'], bins = 100)
plt.xlim([0,75])
plt.show()

# %%
zbins = np.linspace(0.2, 2, 18)
mbins = [38,50,75]

# %%
min(c1['mass']), min(c2['mass']), max(c1['mass']), max(c2['mass'])
# Out:
# (38.002274, 14.00828, 297.56424, 266.29504)

# %%
info = recovery.plot(c1, 'cross', zbins, mbins, shape='steps', log_quantity=False)
plt.title('RedMapper recovery-rate')
plt.show()

# %%
mbins = np.logspace(13, 15,2)

# %%
info = recovery.plot(c2, 'cross', zbins, mbins, shape='steps')
plt.title('CosmoDC2 recovery-rate')
plt.show()
