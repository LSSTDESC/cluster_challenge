# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table, hstack, vstack
from clevar.catalog import ClCatalog
from numpy.ma import masked
import sys
from clevar.match import output_matched_catalog

# %%
inpath = "/sps/lsst/groups/clusters/amico_validation_project/catalogs/matching_cats/amico_redmapper/mag_y/"
am = ClCatalog.read(inpath + 'c1_p_ls4512z115.fits','c1', full = True)
rm = ClCatalog.read(inpath + 'c2_p_ls4512z115.fits','c2', full = True)

# %%
am_inpath = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/AMICO/amico_cats/amico_map_associations_flxzb_mag/mag_y/Catalog_members_ls45z115.fits'

rm_inpath = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/RedMapper/Catalog_members_ls12.fits'
#cdc_inpath = "/sps/lsst/groups/clusters/amico_validation_project/catalogs/cosmoDC2_v1.1.4_small/m13/Catalog_members.fits"

# %%
am_mb = Table.read(am_inpath)
rm_mb = Table.read(rm_inpath)
#cdc_mb = Table.read(cdc_inpath)

# %%
inpath = "/sps/lsst/groups/clusters/amico_validation_project/catalogs/matching_cats/amico_redmapper/mag_y/"
c_merged12 = Table.read(inpath + 'output_catalog_p_ls4512z115.fits')

# %%
c_merged12
# Out:
# <Table length=5501>
# cat1_id  cat1_ra   cat1_dec  ... cat2_mt_multi_other cat2_mt_cross
# bytes11  float64   float64   ...       bytes20           bytes6
# ------- --------- ---------- ... ------------------- -------------
#       1 50.603551 -39.582656 ...                   1             1
#       2 50.113525  -40.03647 ...                   2             2
#       3 50.642569 -41.397661 ...                   3             3
#       4 50.421896 -39.587457 ...                   4             4
#       5 51.069455 -40.426866 ...                   5             5
#       7 51.048368 -41.281951 ...                   7             7
#       8 50.577077 -40.162645 ...                   8             8
#       9 49.910711 -40.070373 ...                   9             9
#      10 51.576131  -40.01887 ...                  10            10
#      11 51.232186 -39.511131 ...                  11            11
#     ...       ...        ... ...                 ...           ...
#  163847 75.279939 -38.128966 ...              163847        163847
#  163854 74.889059 -38.745881 ...              163854        163854
#  163863 74.212269 -39.606088 ...              163863        163863
#  163868 74.011656 -38.620392 ...              163868        163868
#  163871 74.957752 -38.450639 ...              163871        163871
#  163873 74.295421 -37.911266 ...              163873        163873
#  163884 73.587699 -38.247785 ...              163884        163884
#  163895 73.963966 -38.165169 ...              163895        163895
#  163922 75.737958 -38.525094 ...              163922        163922
#  163956 74.230317 -38.351127 ...              163956        163956

# %%
rm_mb
# Out:
# <Table length=379149>
#      id     id_cluster         ra         ...   mag_i     mag_z   ind_cl
#   bytes21    bytes11        float64       ...  float32   float32  int64
# ----------- ---------- ------------------ ... --------- --------- ------
#  1312945563         10 52.520436430812914 ...  17.89911 17.505138      0
#  1312932492         10 52.519490104517175 ...  18.05471 17.676914      0
#  1312932655         10 52.518707152418855 ... 20.486027 20.064653      0
#  1312946401         10 52.518979242173025 ...   21.0543 20.635675      0
#  1312946359         10  52.52323890490535 ... 20.303442  19.94585      0
#  1312932712         10  52.51752041591883 ... 19.791677 19.392906      0
#  1312945743         10 52.522204954216015 ... 20.382519 19.967947      0
#  1312932517         10  52.52449873444964 ... 20.830225 20.387508      0
#  1312946270         10  52.51641230513422 ... 20.537926  20.15959      0
#  1312946366         10  52.52479945586216 ... 21.154459 20.781765      0
#         ...        ...                ... ...       ...       ...    ...
# 11314664829      27511  69.20034153254502 ... 23.406431   22.6216  10254
# 11316256085      27511  69.19678969334423 ... 23.701654 22.985092  10254
# 11316209685      27511  69.19489331044589 ...   24.1529  23.34104  10254
# 11316209655      27511  69.19186886079339 ...   23.6409 22.801983  10254
# 11316256088      27511  69.20282890819462 ...  23.66892 22.920057  10254
# 11316256089      27511  69.20153823494849 ... 23.923014 23.104403  10254
# 11314441880      27511  69.22069097792493 ... 24.326443 23.638124  10254
# 11314429195      27511  69.24683888586972 ... 23.684975 22.957321  10254
# 11314664061      27511   69.2135713739315 ... 24.188942 23.475752  10254
# 11316243907      27511  69.20536248692846 ... 24.080963 23.134525  10254

# %%
c_merged12['cat1_id'] = c_merged12['cat1_id'].astype(int)
c_merged12['cat2_id'] = c_merged12['cat2_id'].astype(int)

# %%
am_mb['matched'] = np.array([i in c_merged12['cat1_id'] for i in am_mb['id_cluster']])

# %%
rm_mb['id_cluster'] = rm_mb['id_cluster'].astype(int)

# %%
rm_mb['matched'] = np.array([i in c_merged12['cat2_id'] for i in rm_mb['id_cluster']])

# %%
rm_mb[rm_mb['matched']==True]
# Out:
# <Table length=246349>
#      id     id_cluster         ra         ... ind_cl matched         z
#   bytes21     int64         float64       ... int64    bool       float64
# ----------- ---------- ------------------ ... ------ ------- ------------------
#  1312945563         10 52.520436430812914 ...      0    True  0.513512909412384
#  1312932492         10 52.519490104517175 ...      0    True  0.513512909412384
#  1312932655         10 52.518707152418855 ...      0    True  0.513512909412384
#  1312946401         10 52.518979242173025 ...      0    True  0.513512909412384
#  1312946359         10  52.52323890490535 ...      0    True  0.513512909412384
#  1312932712         10  52.51752041591883 ...      0    True  0.513512909412384
#  1312945743         10 52.522204954216015 ...      0    True  0.513512909412384
#  1312932517         10  52.52449873444964 ...      0    True  0.513512909412384
#  1312946270         10  52.51641230513422 ...      0    True  0.513512909412384
#  1312946366         10  52.52479945586216 ...      0    True  0.513512909412384
#         ...        ...                ... ...    ...     ...                ...
# 11314193190      20378  67.60838764235231 ...  10249    True 0.9062531590461731
# 11314202605      20378  67.59743074785366 ...  10249    True 0.9062531590461731
# 11313658320      20378  67.60876001129712 ...  10249    True 0.9062531590461731
# 11314202577      20378   67.6005090968113 ...  10249    True 0.9062531590461731
# 11315018770      20378  67.65337080548282 ...  10249    True 0.9062531590461731
# 11314227816      20378  67.59422918975287 ...  10249    True 0.9062531590461731
# 11314202573      20378  67.59163635205242 ...  10249    True 0.9062531590461731
# 11314654100      20378  67.59263991798537 ...  10249    True 0.9062531590461731
# 11314654107      20378  67.59821873991905 ...  10249    True 0.9062531590461731
# 11314227715      20378  67.58645174357515 ...  10249    True 0.9062531590461731

# %%
z_min, z_max = 1.0, 1.15

# %%
rm_cl = c_merged12['cat2_id']
rm_mb['z' ]= 0.0
for cl in rm_cl:
    rm_mb['z'][rm_mb['id_cluster']==cl] = c_merged12[c_merged12['cat2_id']==cl]['cat2_z']

# %%
rm_mb_12 = rm_mb[rm_mb['matched']==True]

# %%
rm_mb_cdt = rm_mb_12[(rm_mb_12['z']>z_min)*(rm_mb_12['z']<z_max)]

# %%
rm_mb_delt = rm_mb_cdt['mag_r'] - rm_mb_cdt['mag_i']

# %%
am_mb_12 = am_mb[am_mb['matched']==True]

# %%
am_mb_cdt = am_mb_12[(am_mb_12['z']>z_min)*(am_mb_12['z']<z_max)]

# %%
am_mb_delt = am_mb_cdt['mag_r'] - am_mb_cdt['mag_i']

# %%
x_bins = np.linspace(20,26.5,25)
y_bins = np.linspace(-0.1,1.3,25)

# %%
am_mb_12
# Out:
# <Table length=3913007>
#     id     id_cluster     ra    ...       mag_y        matched
#   int64      int64     float64  ...      float64         bool
# ---------- ---------- --------- ... ------------------ -------
# 9439468892          1 50.603551 ... 24.812643394756247    True
# 9439469826          1 50.603551 ...   25.0277697058334    True
# 9439471605          1 50.603551 ... 24.852909187614006    True
# 9439595076          1 50.603551 ...  24.75144913382191    True
# 9439675887          1 50.603551 ... 20.540126167451298    True
# 9439677791          1 50.603551 ...  25.18187902638226    True
# 9439697519          1 50.603551 ... 24.962264515414493    True
# 9439698844          1 50.603551 ... 24.441425000209545    True
# 9439706244          1 50.603551 ...  24.32494641831539    True
# 9439763931          1 50.603551 ... 23.593003628416298    True
#        ...        ...       ... ...                ...     ...
# 9130241898     163956 74.230317 ... 24.866506185701454    True
# 9130555179     163956 74.230317 ... 24.807856061925506    True
# 9130607267     163956 74.230317 ...  24.60879578424825    True
# 9130608912     163956 74.230317 ... 24.776280927686567    True
# 9130623607     163956 74.230317 ... 25.248212021880295    True
# 9130628651     163956 74.230317 ...  24.47101996123394    True
# 9130658119     163956 74.230317 ...  24.67286052123561    True
# 9130663614     163956 74.230317 ... 25.044628408030235    True
# 9130992095     163956 74.230317 ... 25.136103407267928    True
# 9131019941     163956 74.230317 ... 24.624421004660462    True

# %%
am_hist = np.histogram2d(am_mb_cdt['mag_i'], am_mb_delt, bins = (x_bins,y_bins),weights = am_mb_cdt['pmem'])
rm_hist = np.histogram2d(rm_mb_cdt['mag_i'], rm_mb_delt, bins = (x_bins,y_bins),weights = rm_mb_cdt['pmem'])

# %%
am_hist = am_hist[0]
rm_hist = rm_hist[0]

# %%
am_hist[am_hist==0] = np.nan
rm_hist[rm_hist==0] = np.nan
x, y = np.meshgrid(x_bins, y_bins)

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (14,5))
#print(x)
#print(y)
c = ax1.pcolormesh(x, y, am_hist.T, cmap='jet', vmin=0, vmax = 5000)
ax1.set_xlabel('mag$_i$', fontsize = 13)
ax1.set_ylabel('mag$_r$ - mag$_i$', fontsize = 13)
ax1.set_title('AMICO ' + str(z_min) + '<z<' + str(z_max), fontsize = 13)
c1 = ax2.pcolormesh(x, y, rm_hist.T, cmap='jet', vmin=0, vmax = 5000)
ax2.set_xlabel('mag$_i$', fontsize = 13)
ax2.set_ylabel('mag$_r$ - mag$_i$', fontsize = 13)
ax2.set_title('RedMapper ' + str(z_min) + '<z<' + str(z_max), fontsize = 13)
ax1.set_xlim([16,28])
ax1.set_ylim([-.1,2])
ax2.set_xlim([16,28])
ax2.set_ylim([-.1,2])
fig.colorbar(c, ax=ax1, label = 'Nb of members')
fig.colorbar(c1, ax=ax2, label = 'Nb of members')
