# %%
import numpy as np
import matplotlib.pyplot as plt
from clevar.match import output_matched_catalog
from clevar.catalog import ClCatalog

# %%
path = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/matching_cats/amico_redmapper/'
c1 = ClCatalog.read(path+'c1_p.fits', 'c1', full = True)
c2 = ClCatalog.read(path+'c2_p.fits', 'c2', full = True)

# %%
matching_folder = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/matching_cats/amico_redmapper/'

# %%
output_matched_catalog(matching_folder+'c1_p.fits', matching_folder+'c2_p.fits',matching_folder+'output_catalog_' + 'p' +'.fits', c1, c2, matching_type='cross', overwrite=True)
c_merged_12 = ClCatalog.read(matching_folder+'output_catalog_' + 'p' + '.fits', 'merged',  full=True)
# Out:
# /sps/lsst/users/namourou/conda_clone_210223/descv1.1/clevar/clevar/catalog.py:267: UserWarning: id column missing, additional one is being created.
#   warnings.warn(

# %%
c_merged_12
# Out:
# <b>merged</b><br></b><b>tags:</b> id(id)<br><b>Radius unit:</b> None<br><div><i>ClData length=359</i>
# <table id="table139886407947200" class="table-striped table-bordered table-condensed">
# <thead><tr><th>id</th><th>cat1_id</th><th>cat1_ra</th><th>cat1_dec</th><th>cat1_z</th><th>cat1_mass</th><th>cat1_mt_self</th><th>cat1_mt_other</th><th>cat1_mt_multi_self</th><th>cat1_mt_multi_other</th><th>cat1_mt_cross</th><th>cat2_id</th><th>cat2_ra</th><th>cat2_dec</th><th>cat2_z</th><th>cat2_mass</th><th>cat2_z_true</th><th>cat2_log_mass</th><th>cat2_mt_self</th><th>cat2_mt_other</th><th>cat2_mt_multi_self</th><th>cat2_mt_multi_other</th><th>cat2_mt_cross</th><th>mt_self</th><th>mt_other</th><th>mt_multi_self</th><th>mt_multi_other</th></tr></thead>
# ...

# %%
c1_nm = []
c1_nm_mass = []
c1_nm_ra = []
c1_nm_dec = []
c1_nm_z = []
for id in c1['id']:
    if id not in c_merged_12['cat2_mt_cross']:
        cdt = c1[c1['id']==id]
        c1_nm.append(id)
        c1_nm_mass.append(cdt['mass'])
        c1_nm_ra.append(cdt['ra'])
        c1_nm_dec.append(cdt['dec'])
        c1_nm_z.append(cdt['z'])
print('c1 ok')
# Out:
# c1 ok

# %%
c1_nm_massl = []
c1_nm_ral = []
c1_nm_decl = []
c1_nm_zl = []
for i in range(len(c1_nm_z)):
    c1_nm_massl.append(c1_nm_mass[i][0])
    c1_nm_ral.append(c1_nm_ra[i][0])
    c1_nm_decl.append(c1_nm_dec[i][0])
    c1_nm_zl.append(c1_nm_z[i][0])

# %%
c2_nm = []
c2_nm_mass = []
c2_nm_ra = []
c2_nm_dec = []
c2_nm_z = []
for id in c2['id']:
    if id not in c_merged_12['cat1_mt_cross']:
        cdt = c2[c2['id']==id]
        c2_nm.append(id)
        c2_nm_mass.append(cdt['mass'])
        c2_nm_ra.append(cdt['ra'])
        c2_nm_dec.append(cdt['dec'])
        c2_nm_z.append(cdt['z'])
print('c2 ok')
# Out:
# c2 ok

# %%
c2_nm_massl = []
c2_nm_ral = []
c2_nm_decl = []
c2_nm_zl = []
for i in range(len(c2_nm_z)):
    c2_nm_massl.append(c2_nm_mass[i][0])
    c2_nm_ral.append(c2_nm_ra[i][0])
    c2_nm_decl.append(c2_nm_dec[i][0])
    c2_nm_zl.append(c2_nm_z[i][0])

# %%
len(c1), len(c2)
# Out:
# (660, 536)

# %%
len(c_merged_12['cat1_mt_cross']), len(c_merged_12['cat2_mt_cross'])
# Out:
# (359, 359)

# %%
len(c1_nm), len(c2_nm)
# Out:
# (301, 177)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (20,7))
ax1.hist(c1['mass'], bins = np.linspace(30,50,15), label = 'AM full', histtype = 'step')
ax1.hist(c_merged_12['cat1_mass'], bins = np.linspace(30,50,15), label = 'AM matched', histtype = 'step')
ax1.hist(c1_nm_massl, bins = np.linspace(30,50,15), label = 'AM not matched', histtype = 'step')
ax1.legend()
ax1.set_xlabel('mass')
ax2.hist(c1['z'], bins = np.linspace(0,1.75,15), label = 'AM full', histtype = 'step')
ax2.hist(c_merged_12['cat1_z'], bins = np.linspace(0,1.75,15), label = 'AM matched', histtype = 'step')
ax2.hist(c1_nm_zl, bins = np.linspace(0,1.75,15), label = 'AM not matched', histtype = 'step')
ax2.legend()
ax2.set_xlabel('z')
ax3.hist(c1['ra'], bins =15, label = 'AM full', histtype = 'step')
ax3.hist(c_merged_12['cat1_ra'], bins = 15, label = 'AM matched', histtype = 'step')
ax3.hist(c1_nm_ral, bins = 15, label = 'AM not matched', histtype = 'step')
ax3.legend()
ax3.set_xlabel('ra')
# Out:
# Text(0.5, 0, 'ra')

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (20,7))
ax1.hist(c2['mass'], bins = np.linspace(20,50,15), label = 'RM full', histtype = 'step')
ax1.hist(c_merged_12['cat2_mass'], bins = np.linspace(20,50,15), label = 'RM matched', histtype = 'step')
ax1.hist(c2_nm_massl, bins = np.linspace(20,50,15), label = 'RM not matched', histtype = 'step')
ax1.set_xlabel('mass')
ax1.legend()
ax2.hist(c2['z'], bins = np.linspace(0,1.3,15), label = 'RM full', histtype = 'step')
ax2.hist(c_merged_12['cat2_z'], bins = np.linspace(0,1.3,15), label = 'RM matched', histtype = 'step')
ax2.hist(c2_nm_zl, bins = np.linspace(0,1.3,15), label = 'RM not matched', histtype = 'step')
ax2.legend()
ax2.set_xlabel('z')
ax3.hist(c2['ra'], bins =15, label = 'RM full', histtype = 'step')
ax3.hist(c_merged_12['cat2_ra'], bins = 15, label = 'RM matched', histtype = 'step')
ax3.hist(c2_nm_ral, bins = 15, label = 'RM not matched', histtype = 'step')
ax3.legend()
ax3.set_xlabel('ra')
# Out:
# Text(0.5, 0, 'ra')

# %%
plt.scatter(c_merged_12['cat1_z'],c_merged_12['cat2_z'], s=10)
plt.xlabel('$z_{AMICO}$')
plt.ylabel('$z_{RedMapper}$')
# Out:
# Text(0, 0.5, '$z_{RedMapper}$')

# %%
delt = (c_merged_12['cat1_z']-c_merged_12['cat2_z'])/(1+c_merged_12['cat2_z'])

# %%
plt.hist(delt, bins = 15, histtype = 'step')
plt.xlabel('$(z_{AM}-z_{RM})/(1+z_{RM})$')
# Out:
# Text(0.5, 0, '$(z_{AM}-z_{RM})/(1+z_{RM})$')

# %%
c2_nm_mass[2][0]

# %%
c2_nmc = []
for id in c2_nm:
    c2_nmc.append(c2[c2['id']==id])

# %%
#faire un fit
plt.scatter(c_merged_12['cat1_mass'], c_merged_12['cat2_mass'], s=5)
plt.xlim([0,75])
plt.ylim([0,75])
plt.title('rich - rich')
plt.xlabel('amico')
plt.ylabel('RedMapper')
plt.legend()

# %%
c2.read_members(rm_inpath + 'Catalog_members.fits', full = True)

# %%
n, rich = np.histogram(c2['mass'], bins = np.linspace(5,50,10))

# %%
rich

# %%
n

# %%
richness = []
for i in range(len(rich)-1):
    richness.append((rich[i]+rich[i+1])/2)

# %%
density = n/57.071968

# %%
plt.plot(richness, density, marker = '+')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('richness')
plt.ylabel('density')

# %%
sky_area_sq_deg = 57.071968
rich_bins = np.linspace(5, 75, 10)
cdf2 = np.searchsorted(c2["mass"], mag_bins, sorter=c2["mass"].argsort())
cdf2 = len(c2)-cdf2
g2, = plt.semilogy(rich_bins, cdf2 / sky_area_sq_deg, color = 'red')
plt.xlabel("richness");
plt.ylabel("Density (cl/deg2)");
plt.legend()
plt.grid(which='major', axis='both', linestyle='-', linewidth='0.5', color='grey')
plt.grid(which='minor', axis='both', linestyle=':', linewidth='0.5', color='grey')
plt.close()

# %%
rm = ClCatalog.read('/sps/lsst/users/tguillem/DESC/desc_april_2022/cluster_challenge/clevar_catalogs/redmapper/full_pmem_small/cosmoDC2_v1.1.4_redmapper_v0.8.1/Catalog.fits', 'rm', full =True)

# %%
rm_mb = rm.read_members('/sps/lsst/users/tguillem/DESC/desc_april_2022/cluster_challenge/clevar_catalogs/redmapper/full_pmem_small/cosmoDC2_v1.1.4_redmapper_v0.8.1/Catalog_members.fits', full =True)

# %%
rm.members
# Out:
# <b>members</b><br><b>tags:</b> id(id), id_cluster(id_cluster), ra(ra), dec(dec), pmem(pmem)<br><div><i>ClData length=113048</i>
# <table id="table139886407889968" class="table-striped table-bordered table-condensed">
# <thead><tr><th>id</th><th>id_cluster</th><th>ra</th><th>dec</th><th>pmem</th><th>mag_r</th><th>mag_i</th><th>mag_z</th><th>ind_cl</th></tr></thead>
# <thead><tr><th>str21</th><th>str11</th><th>float64</th><th>float64</th><th>float32</th><th>float32</th><th>float32</th><th>float32</th><th>int64</th></tr></thead>
# <tr><td>8064212696</td><td>26</td><td>67.04118044229672</td><td>-36.65553761954279</td><td>0.99921656</td><td>21.258728</td><td>20.214851</td><td>19.428509</td><td>0</td></tr>
# <tr><td>8064240727</td><td>26</td><td>67.03971963378734</td><td>-36.65522571193022</td><td>0.99659103</td><td>23.312243</td><td>22.278286</td><td>21.518162</td><td>0</td></tr>
# ...

# %%
rm = rm[rm['mass']>=20]

# %%
rm.members
# Out:
# <b>members</b><br><b>tags:</b> id(id), id_cluster(id_cluster), ra(ra), dec(dec), pmem(pmem)<br><div><i>ClData length=27610</i>
# <table id="table139886407348144" class="table-striped table-bordered table-condensed">
# <thead><tr><th>id</th><th>id_cluster</th><th>ra</th><th>dec</th><th>pmem</th><th>mag_r</th><th>mag_i</th><th>mag_z</th><th>ind_cl</th></tr></thead>
# <thead><tr><th>str21</th><th>str11</th><th>float64</th><th>float64</th><th>float32</th><th>float32</th><th>float32</th><th>float32</th><th>int64</th></tr></thead>
# <tr><td>8064212696</td><td>26</td><td>67.04118044229672</td><td>-36.65553761954279</td><td>0.99921656</td><td>21.258728</td><td>20.214851</td><td>19.428509</td><td>0</td></tr>
# <tr><td>8064240727</td><td>26</td><td>67.03971963378734</td><td>-36.65522571193022</td><td>0.99659103</td><td>23.312243</td><td>22.278286</td><td>21.518162</td><td>0</td></tr>
# ...

# %%
out = '/sps/lsst/users/tguillem/DESC/desc_april_2022/cluster_challenge/clevar_catalogs/redmapper/full_pmem_small/cosmoDC2_v1.1.4_redmapper_v0.8.1/'

# %%
rm.write('/sps/lsst/groups/clusters/amico_validation_project/catalogs/RedMapper/' + 'Catalogls20.fits', overwrite = True)

# %%
rm.members.write('/sps/lsst/groups/clusters/amico_validation_project/catalogs/RedMapper/' + 'Catalog_membersls20.fits', overwrite = True)
