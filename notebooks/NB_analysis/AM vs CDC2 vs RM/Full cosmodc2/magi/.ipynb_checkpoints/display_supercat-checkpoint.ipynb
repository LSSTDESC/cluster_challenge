# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table, hstack, vstack
from clevar.catalog import ClCatalog
from numpy.ma import masked
import sys
from clevar.match import output_matched_catalog

# %%
inpath = "/sps/lsst/groups/clusters/amico_validation_project/catalogs/"
amico_path = inpath + 'AMICO/amico_cats/amico_map_associations_flxzb_mag/'

rm_path = '/sps/lsst/users/tguillem/DESC/desc_april_2022/cluster_challenge/clevar_catalogs/redmapper/full_pmem/cosmoDC2_v1.1.4_redmapper_v0.8.1/'

dc2_path = '/sps/lsst/users/tguillem/DESC/desc_april_2022/cluster_challenge/clevar_catalogs/cosmoDC2/with_m200c/cosmoDC2_v1.1.4/'

# %%
am_cl = Table.read(amico_path + 'Catalog.fits')
am_mb = Table.read(amico_path + 'Catalog_members.fits')

# %%
rm_cl =  Table.read(rm_path + 'Catalog.fits')
rm_mb = Table.read(rm_path + 'Catalog_members.fits')

# %%
#MAP

# %%
plt.figure(figsize = (10,7))
plt.scatter(am_cl['ra'], am_cl['dec'], c=am_cl['z'], s =1, cmap = 'jet')
plt.colorbar(label = 'z')
plt.xlabel('ra', fontsize = 15)
plt.ylabel('dec', fontsize = 15)
plt.xlim([45,80])
plt.ylim([-50,-20])
plt.title('Map of AMICOs sky')
# Out:
# Text(0.5, 1.0, 'Map of AMICOs sky')

# %%
plt.hist(am_cl['z'], bins = 50)
plt.xlabel('z', fontsize = 15)
plt.show()

# %%
plt.hist(am_cl['mass'], bins = 100)
plt.xlabel('$\lambda_*$', fontsize = 15)
#plt.xlim([0,150])
plt.xscale('log')
plt.show()
