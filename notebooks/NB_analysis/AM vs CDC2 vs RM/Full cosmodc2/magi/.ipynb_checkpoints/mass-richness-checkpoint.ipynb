# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table, hstack, vstack
from clevar.catalog import ClCatalog
from numpy.ma import masked
import sys
from clevar.match import output_matched_catalog

# %%
path1 = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/matching_cats/amico_cosmoDC2/mag_i/'
c_merged_12 = ClCatalog.read(path1+'output_catalog_' + 'p' + '.fits', 'merged',  full=True)
path2 = '/sps/lsst/groups/clusters/amico_validation_project/catalogs/matching_cats/redmapper_cosmoDC2/'
c_merged_23 = ClCatalog.read(path2+'output_catalog_' + 'p' + '.fits', 'merged',  full=True)
# Out:
# /sps/lsst/users/namourou/conda_clone_210223/descv1.1/clevar/clevar/catalog.py:280: UserWarning: id column missing, additional one is being created.
#   warnings.warn(f"{id_name} column missing, additional one is being created.")

# %%
c_merged_23
# Out:
# <b>merged</b><br></b><b>tags:</b> id(id)<br><b>Radius unit:</b> None<br><div><i>ClData length=44480</i>
# <table id="table139815561854160" class="table-striped table-bordered table-condensed">
# <thead><tr><th>id</th><th>cat1_id</th><th>cat1_ra</th><th>cat1_dec</th><th>cat1_z</th><th>cat1_mass</th><th>cat1_z_true</th><th>cat1_log_mass</th><th>cat1_mt_self</th><th>cat1_mt_other</th><th>cat1_mt_multi_self</th><th>cat1_mt_multi_other</th><th>cat1_mt_cross</th><th>cat2_id</th><th>cat2_ra</th><th>cat2_dec</th><th>cat2_z</th><th>cat2_mass</th><th>cat2_log_mass</th><th>cat2_m200c</th><th>cat2_log_m200c</th><th>cat2_mt_self</th><th>cat2_mt_other</th><th>cat2_mt_multi_self</th><th>cat2_mt_multi_other</th><th>cat2_mt_cross</th><th>mt_self</th><th>mt_other</th><th>mt_multi_self</th><th>mt_multi_other</th></tr></thead>
# ...

# %%
c_merged_12c = c_merged_12[c_merged_12['cat1_z']<=1.15]

# %%
#plt.scatter(c_merged_12['cat1_mass'], c_merged_12['cat2_mass'], s=5)
plt.scatter(c_merged_12c['cat2_log_m200c'], np.log(c_merged_12c['cat1_mass']), s=5)
#plt.scatter(c_merged_23['cat1_mass'], c_merged_23['cat2_mass'], s=5)
plt.ylim([0,5.5])
plt.xlim([13,15])
plt.title('AMICO mass richness scatter plot', fontsize = 15)
plt.ylabel('log($\lambda$)', fontsize = 14)
plt.xlabel('log10($M_{200c}$)', fontsize = 13)
# Out:
# /tmp/ipykernel_11950/1024097507.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.scatter(c_merged_12c['cat2_log_m200c'], np.log(c_merged_12c['cat1_mass']), s=5)
# Text(0.5, 0, 'log10($M_{200c}$)')

# %%
#plt.scatter(c_merged_12['cat1_mass'], c_merged_12['cat2_mass'], s=5)
plt.title('RedMapper mass richness scatter plot', fontsize = 15)
plt.scatter(c_merged_23['cat2_log_m200c'], np.log(c_merged_23['cat1_mass']), s=5)
#plt.scatter(c_merged_23['cat1_mass'], c_merged_23['cat2_mass'], s=5)
plt.ylim([0,5.5])
plt.xlim([13,15])
plt.ylabel('log($\lambda$)', fontsize = 14)
plt.xlabel('log10($M_{200c}$)', fontsize = 13)
# Out:
# Text(0.5, 0, 'log10($M_{200c}$)')
