# %%
import numpy as np
from astropy.table import Table
import matplotlib.pyplot as plt

# %%
inpath = "/sps/lsst/groups/clusters/amico_validation_project/catalogs/CosmoDC2/cosmoDC2_photoz_flexzboost/m13.0_5/"

# %%
cdc = Table.read(inpath + "Catalog.fits")
cdc_mb = Table.read(inpath + "Catalog_members.fits")

# %%
cdc
# Out:
# <Table length=347925>
#       id              ra         ...       m200c            log_m200c
#     int64          float64       ...      float64            float64
# ------------- ------------------ ... ------------------ ------------------
#    1600020475 50.775875822529436 ... 18901145086557.746 13.276488115798056
#    2700020475 49.466814189348334 ...  15062094204754.93 13.177885359536557
#   17200020453  50.16585579512233 ... 20441971397588.734 13.310522776287003
#   19000020453  49.51865674267036 ... 10668658238016.902 13.028109803073287
#   32800020453  51.49405530538187 ... 10371945197971.832 13.015860213430779
#   32300020442  51.48013416475692 ...  11587427913554.93 13.063987045375406
#   33400020442  50.63847703474752 ... 15481136188574.648 13.189802831173791
#   52100020442  51.30452190097757 ...  21053617593329.58 13.323326730377568
#   11500020432  50.75814114328289 ... 10135095509453.521 13.005827845681537
#   28800020432  50.48012643219498 ... 14838258673577.465 13.171382937814364
#           ...                ... ...                ...                ...
# 5655500193124  72.78324476354646 ... 14187571482681.691 13.151908062692687
# 5671700193124  73.82068148538134 ... 17071415411380.283 13.232269530480194
#  922300193121  74.08471466040369 ... 11100714379177.465 13.045350928421932
# 1250600193121  72.16015005667711 ...  11785236606918.31  13.07133830608372
# 1618200193121  74.70034657468187 ... 14041817941814.086 13.147423337921126
# 1805500193121  73.16946169058204 ...  13726884786118.31 13.137571988532843
# 2529600193121  73.94017550995466 ... 11178796369487.324  13.04839504521138
# 4540300193121  73.89058920742978 ... 11387016241036.621 13.056409940074486
# 5541600193121  72.49711523026612 ... 12339621691853.521 13.091301845300224
# 5788500193121  72.49206267522683 ... 10697288793419.719 13.029273720558367

# %%
plt.scatter(cdc['ra'], cdc['dec'], s=.1, alpha = .5)
plt.ylabel('dec', fontsize = 15)
plt.xlabel('ra', fontsize = 15)
plt.savefig('/pbs/home/n/namourou/test_jupyter/cluster_challenge/plots/input_skymap.png', format='png', transparent=True)
plt.show()
# Out:
# (13.00011064929296, 13.499998150223101)
