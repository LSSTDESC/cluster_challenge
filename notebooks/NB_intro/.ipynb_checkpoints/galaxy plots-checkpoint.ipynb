# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
import GCRCatalogs
from GCRCatalogs.helpers.tract_catalogs import tract_filter, sample_filter
from GCRCatalogs import GCRQuery
from astropy.table import Table

# %%
cat = GCRCatalogs.load_catalog("cosmoDC2_v1.1.4_small")

# %%
galaxy_data = cat.get_quantities(['ra', 'dec', 'mag_g', 'mag_i', 'mag_r', 'mag_z','mag_y', 'halo_id', 'halo_mass', 'position_x', 'position_y', 'redshift'], 
                                 filters=['halo_mass>1e14'])

# %%
galaxy_data
# Out:
# {'dec': array([-40.51640122, -40.52954951, -40.53940498, ..., -37.37431927,
#         -37.38050473, -37.37854147]),
#  'mag_g': array([18.97016838, 24.18311438, 20.32519502, ..., 31.42174146,
#         31.54280663, 31.29320627]),
#  'mag_i': array([17.3348172 , 22.64582953, 18.46764345, ..., 29.23623846,
#         29.35730363, 28.72623926]),
#  'mag_y': array([16.89182594, 22.21544394, 17.9439847 , ..., 27.45286748,
#         27.57393266, 27.13285929]),
#  'mag_r': array([17.79581383, 23.08372435, 19.02541513, ..., 30.07627676,
#         30.19734193, 29.59980494]),
#  'position_y': array([ 674.53888369,  674.67190917,  676.53941302, ..., 4078.30347189,
#         4078.03481725, 4077.68267607]),
#  'ra': array([62.55277181, 62.57667676, 62.74927533, ..., 64.78557483,
#         64.78893367, 64.77823595]),
#  'position_x': array([ 350.34873855,  350.05998208,  348.44057325, ..., 1919.83798542,
#         1919.4273585 , 1920.18991839]),
#  'redshift': array([0.24844585, 0.24960488, 0.24924862, ..., 2.33245869, 2.31811657,
#         2.33098214]),
#  'mag_z': array([17.09539345, 22.41203054, 18.16641397, ..., 28.48581121,
#         28.60687638, 28.09192759]),
#  'halo_mass': array([1.20235100e+14, 1.20235100e+14, 1.20235100e+14, ...,
#         1.56339196e+14, 1.56339196e+14, 1.56339196e+14]),
#  'halo_id': array([ 131800155392,  131800155392,  131800155392, ..., 3820800128148,
#         3820800128148, 3820800128148])}

# %%
DC2_cat_name = 'cosmoDC2_v1.1.4_small'

outpath = "/sps/lsst/groups/clusters/amico_validation_project/catalogs/" + DC2_cat_name + "/m13/"

# %%
truth_data, gc_truth = DC2_cat_open(DC2_cat_name, min_halo_mass, cluster_only=False)
galaxy_data = truth_data[truth_data['is_central']==False]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 truth_data, gc_truth = DC2_cat_open(DC2_cat_name, min_halo_mass, cluster_only=False)
#       2 galaxy_data = truth_data[truth_data['is_central']==False]
#
# NameError: name 'DC2_cat_open' is not defined

# %%
c1_members = Table([galaxy_data['galaxy_id'],galaxy_data['halo_id'],galaxy_data['ra'],galaxy_data['dec'],galaxy_data['redshift'], galaxy_data['mag_g'], galaxy_data['mag_i'], galaxy_data['mag_r'], galaxy_data['mag_z'], galaxy_data['mag_y']],names=('id','id_cluster','ra','dec','z','mag_g', 'mag_i', 'mag_r', 'mag_z', 'mag_y'))

# %%
print(cat.list_all_quantities())
# Out:
# ['mag_g_sdss', 'mag_true_r_sdss_no_host_extinction', 'velocity_x', 'mag_u_sdss_no_host_extinction', 'Mag_true_r_lsst_z0', 'sed_6548_406_disk', 'mag_true_g', 'mag_y', 'sed_1933_474_disk', 'sed_5148_319_no_host_extinction', 'mag_true_Y_lsst_no_host_extinction', 'Mag_true_u_lsst_z0', 'A_v_bulge', 'sed_11467_1710_no_host_extinction', 'mag_r_lsst', 'Mag_true_z_sdss_z0', 'sed_1246_306', 'position_z', 'sed_17402_2596_bulge_no_host_extinction', 'ellipticity_disk_true', 'sed_3184_197_disk', 'sed_7385_458_no_host_extinction', 'mag_r_sdss', 'sed_13177_1966', 'redshift', 'Mag_true_Y_lsst_z0_no_host_extinction', 'sed_4299_266_bulge', 'sed_5806_360_no_host_extinction', 'ellipticity_2_disk_true', 'sed_9978_1489_no_host_extinction', 'sed_7843_486_disk', 'sed_6548_406_no_host_extinction', 'halo_mass', 'sed_7843_486_disk_no_host_extinction', 'shear_2_phosim', 'velocity_z', 'mag_g_lsst', 'sed_1000_246_disk', 'sed_4299_266_bulge_no_host_extinction', 'sed_1000_246_no_host_extinction', 'Mag_true_z_lsst_z0_no_host_extinction', 'sed_2998_186_no_host_extinction', 'sed_1246_306_disk_no_host_extinction', 'sed_4048_251', 'mag_g', 'sed_3590_222_bulge', 'sed_2407_591_disk', 'sed_8329_517', 'size_minor_true', 'sed_4848_300_bulge', 'sed_6954_431_disk_no_host_extinction', 'sed_9395_583', 'sed_8329_517_disk', 'mag_true_g_lsst_no_host_extinction', 'Mag_true_r_lsst_z0_no_host_extinction', 'sed_3590_222_bulge_no_host_extinction', 'sed_15143_2259_disk_no_host_extinction', 'shear_2_treecorr', 'mag_true_g_lsst', 'size_disk_true', 'ellipticity_bulge_true', 'mag_true_r_lsst_no_host_extinction', 'mag_u_lsst', 'sed_6548_406_bulge', 'sed_4565_283_bulge', 'convergence', 'sersic_disk', 'mag_Y_lsst', 'sed_4565_283_no_host_extinction', 'size_minor_bulge_true', 'sed_1552_381_bulge_no_host_extinction', 'Mag_true_y_lsst_z0_no_host_extinction', 'sed_13177_1966_disk', 'sed_1933_474_no_host_extinction', 'mag_true_i', 'mag_u_sdss', 'sed_5467_339_disk_no_host_extinction', 'sed_11467_1710_disk', 'Mag_true_g_lsst_z0_no_host_extinction', 'mag_z_sdss', 'sed_1933_474_bulge_no_host_extinction', 'position_angle_true', 'R_v_disk', 'mag_true_i_lsst_no_host_extinction', 'sed_3381_209_disk_no_host_extinction', 'sed_9395_583_disk', 'sed_9978_1489_disk', 'galaxy_id', 'R_v_bulge', 'mag_true_i_lsst', 'sed_4048_251_bulge', 'mag_true_y_lsst', 'sed_1000_246_disk_no_host_extinction', 'sed_3812_236_bulge', 'stellar_mass_bulge', 'sed_9395_583_no_host_extinction', 'sed_5467_339_disk', 'sed_15143_2259_bulge', 'sed_6954_431_bulge_no_host_extinction', 'sed_11467_1710', 'mag_true_r_sdss', 'velocity_y', 'stellar_mass', 'mag_i_sdss_no_host_extinction', 'sed_9978_1489', 'mag_z_sdss_no_host_extinction', 'Mag_true_i_lsst_z0', 'mag_u_lsst_no_host_extinction', 'redshift_true', 'position_y', 'sed_4048_251_disk', 'sed_7385_458_bulge', 'sed_3381_209_bulge', 'sed_5806_360_disk_no_host_extinction', 'sed_2998_186_bulge_no_host_extinction', 'magnification', 'sed_8329_517_disk_no_host_extinction', 'Mag_true_u_sdss_z0', 'sed_6548_406_disk_no_host_extinction', 'mag_u', 'sed_7843_486_no_host_extinction', 'halo_id', 'mag_z_lsst', 'sed_3184_197_no_host_extinction', 'sed_1933_474_bulge', 'mag_true_z_sdss', 'A_v', 'mag_true_y', 'sed_3381_209_no_host_extinction', 'Mag_true_z_lsst_z0', 'sed_11467_1710_disk_no_host_extinction', 'sed_7843_486', 'Mag_true_g_sdss_z0', 'sed_2998_186_disk', 'sed_3812_236_no_host_extinction', 'position_x', 'mag_true_r', 'sed_3381_209', 'sed_4848_300_disk', 'sed_13177_1966_bulge_no_host_extinction', 'sersic_bulge', 'sed_5148_319_disk_no_host_extinction', 'sed_9395_583_bulge_no_host_extinction', 'sed_4299_266_no_host_extinction', 'A_v_disk', 'sed_2407_591_disk_no_host_extinction', 'sed_6548_406', 'mag_true_y_lsst_no_host_extinction', 'sed_5467_339_bulge', 'sed_4565_283_bulge_no_host_extinction', 'sed_4848_300_bulge_no_host_extinction', 'sed_3590_222_no_host_extinction', 'sed_3812_236_disk_no_host_extinction', 'stellar_mass_disk', 'dec_true', 'ellipticity_1_disk_true', 'Mag_true_r_sdss_z0', 'mag_true_g_sdss' ...

# %%
galaxy_data = cat.get_quantities(['ra', 'dec', 'mag_i', 'mag_r', 'mag_z', 'halo_id', 'halo_mass', 'position_x', 'position_y', 'redshift'], 
                                 filters=['halo_mass>1e13'])
cluster_data = cat.get_quantities(['ra','dec', 'halo_mass', 'halo_id', 'position_x', 'position_y', 'redshift', 'mag_i'], 
                                 filters=['is_central', 'halo_mass > 1e13'])

# %% [markdown]
# ## Galaxy density versus mag_i (i.e. n_galaxies/0.05deg2/0.05mag)

# %%
plt.hist(galaxy_data['mag_i'], bins = 100,histtype='step', label = '$mag_i$')
plt.hist(galaxy_data['mag_r'], bins = 100,histtype='step', label = '$mag_r$')
plt.hist(galaxy_data['mag_z'], bins = 100,histtype='step', label = '$mag_z$')
plt.xlabel("Magnitude", fontsize = 15)
plt.ylabel('Number of galaxies', fontsize = 15)
plt.legend()
plt.show()
plt.savefig('nber_of_gal_mag')

# %%
n_gal, mag_i = np.histogram(galaxy_data['mag_i'], bins = 25)
density = n_gal/57.071968 #From text file found on gcr github
plt.plot(mag_i[0:25], density, marker = '+', linestyle = 'none')
plt.axvline(x=24, color = 'black')
plt.yscale('log')
plt.xlabel('Magnitude', fontsize = 15)
plt.ylabel('Galaxy density', fontsize = 15)
plt.savefig('galdens_mag')

# %% [markdown]
# ## Split in a few redshift bins and plot mag_x for bands r, i, z

# %%
import pandas as pd
galaxy_data_df = pd.DataFrame(galaxy_data)
gal_1 = galaxy_data_df[(galaxy_data_df['redshift']>.4) & (galaxy_data_df['redshift']<.6)]
gal_2 = galaxy_data_df[(galaxy_data_df['redshift']>.6) & (galaxy_data_df['redshift']<.8)]
gal_3 = galaxy_data_df[(galaxy_data_df['redshift']>.8) & (galaxy_data_df['redshift']<1.0)]
gal_4 = galaxy_data_df[(galaxy_data_df['redshift']>1.0) & (galaxy_data_df['redshift']<1.2)]
gal_5 = galaxy_data_df[(galaxy_data_df['redshift']>1.2) & (galaxy_data_df['redshift']<1.4)]
gal_6 = galaxy_data_df[(galaxy_data_df['redshift']>1.4) & (galaxy_data_df['redshift']<1.6)]

# %%
fig, ((ax1, ax2, ax3),(ax4,ax5,ax6)) = plt.subplots(2,3, figsize = (20,10))

ax1.hist(gal_1['mag_i'], bins = 100,histtype='step', label ='$mag_i$')
ax1.hist(gal_1['mag_r'], bins = 100,histtype='step', label ='$mag_r$')
ax1.hist(gal_1['mag_z'], bins = 100,histtype='step', label ='$mag_z$')
ax1.set_title('.4<z<.6')
ax1.legend()
ax1.set_xlabel('mag')
ax1.set_ylabel('number of obj')

ax2.hist(gal_2['mag_i'], bins = 100,histtype='step', label ='$mag_i$')
ax2.hist(gal_2['mag_r'], bins = 100,histtype='step', label ='$mag_r$')
ax2.hist(gal_2['mag_z'], bins = 100,histtype='step', label ='$mag_z$')
ax2.legend()
ax2.set_title('.6<z<.8')

ax3.hist(gal_3['mag_i'], bins = 100,histtype='step', label ='$mag_i$')
ax3.hist(gal_3['mag_r'], bins = 100,histtype='step', label ='$mag_r$')
ax3.hist(gal_3['mag_z'], bins = 100,histtype='step', label ='$mag_z$')
ax3.legend()
ax3.set_title('.8<z<1.0')

ax4.hist(gal_4['mag_i'], bins = 100,histtype='step', label ='$mag_i$')
ax4.hist(gal_4['mag_r'], bins = 100,histtype='step', label ='$mag_r$')
ax4.hist(gal_4['mag_z'], bins = 100,histtype='step', label ='$mag_z$')
ax4.legend()
ax4.set_title('1.0<z<1.2')

ax5.hist(gal_5['mag_i'], bins = 100,histtype='step', label ='$mag_i$')
ax5.hist(gal_5['mag_r'], bins = 100,histtype='step', label ='$mag_r$')
ax5.hist(gal_5['mag_z'], bins = 100,histtype='step', label ='$mag_z$')
ax5.legend()
ax5.set_title('1.2<z<1.4')

ax6.hist(gal_6['mag_i'], bins = 100,histtype='step', label ='$mag_i$')
ax6.hist(gal_6['mag_r'], bins = 100,histtype='step', label ='$mag_r$')
ax6.hist(gal_6['mag_z'], bins = 100,histtype='step', label ='$mag_z$')
ax6.legend()
ax6.set_title('1.4<z<1.6')

plt.show()
fig.savefig('subplot')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [88], line 42
#      39 ax6.set_title('1.4<z<1.6')
#      41 plt.show()
# ---> 42 fig.set_title('infinite subplot')
#
# AttributeError: 'Figure' object has no attribute 'set_title'

# %%
import pandas as pd
galaxy_data_df = pd.DataFrame(galaxy_data)
bin_corners = np.linspace(min(galaxy_data_df['redshift']),max(galaxy_data_df['redshift']),10)
bin_list = [[bin_corners[i],bin_corners[i+1]] for i in range(len(bin_corners)-1)]
mag_r = []
mag_i = []
mag_z = []
for bin in bin_list:
    mask = (galaxy_data_df['redshift'] < bin[1]) & (galaxy_data_df['redshift'] > bin[0])
    mag_r_cut = galaxy_data_df['mag_r'][mask]
    mag_i_cut = galaxy_data_df['mag_i'][mask]
    mag_z_cut = galaxy_data_df['mag_z'][mask]
    mag_r.append(np.mean(mag_r_cut)) #Append new point to list
    mag_i.append(np.mean(mag_i_cut))
    mag_z.append(np.mean(mag_z_cut))
mid_bin = np.mean(bin_list,  axis=1)
# Out:
# /tmp/ipykernel_8115/1588134300.py:9: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead.
#   mask = (galaxy_data_df['redshift'] < bin[1]) * (galaxy_data_df['redshift'] > bin[0])

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (20,6))
ax1.errorbar(mid_bin, mag_r, marker = '+', linestyle = 'none',markersize = 10)
ax2.errorbar(mid_bin, mag_i, marker = '+', linestyle = 'none',markersize = 10)
ax3.errorbar(mid_bin, mag_z, marker = '+', linestyle = 'none',markersize = 10)
ax_l = [ax1,ax2,ax3]
for ax in ax_l:
    ax.set_ylim(16.5,19)
    ax.set_xlabel('redshift', fontsize = 20)
ax1.set_ylabel('$mag_r$', fontsize = 20)
ax2.set_ylabel('$mag_i$', fontsize = 20)
ax3.set_ylabel('$mag_z$', fontsize = 20)
plt.savefig('subplot2')

# %% [markdown]
# ## Association galaxies - host halo : select one halo, find his members and plot ra/dec map of the cluster with his members

# %%
#finding an interesting halo
cluster_data = Table(cluster_data)
j = 0
for i, cluster in enumerate(cluster_data):
    if i>150:
        break
    members = GCRQuery('halo_id == {}'.format(cluster['halo_id'])).filter(galaxy_data)
    if len(members['ra'])>j:
        cl_name = members['halo_id'][0]
        j = len(members['ra'])

# %%
members['mag_i']
# Out:
# array([16.96955957, 18.02942916, 17.98275782, 17.97357813, 17.85096754,
#        17.83154693, 18.14052994, 18.40560167, 18.23728616, 18.34324157,
#        18.28263472])

# %%
#Quick idea : add the central galaxy to the plot with a cross or an other sign

# %%
#Select one halo and track its members
cut_members = GCRQuery('halo_id == {}'.format(cl_name))
members = cut_members.filter(galaxy_data)
plt.scatter(members['ra'], members['dec'], s=20)
plt.xlabel('ra')
plt.ylabel('dec')
plt.title('halo_members_ra_dec_plot')
plt.savefig('members of a halo')
